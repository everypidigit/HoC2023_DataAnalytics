# %%
import pandas as pd

# %%
# reading data

df = pd.read_csv("Dec4.csv")
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 # reading data
# ----> 3 df = pd.read_csv("Dec4.csv")
#       4 df
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
# dropping rows in which all columns have the same values

df1 = df.drop_duplicates()

df1.to_csv("cleaned_data.csv", index=False)
df1
# Out:
#                     name                       email       region
# 0     daniyar.kakimbekov            asdasd@asdsd.com  Алматинская  \
# 2     daniyar.kakimbekov            asdasd@asdsd.com  Алматинская
# 5     daniyar.kakimbekov            asdasd@asdsd.com       Алматы
# 11    daniyar.kakimbekov            asdasd@asdsd.com       Астана
# 17    daniyar.kakimbekov            asdasd@asdsd.com       Алматы
# ...                  ...                         ...          ...
# 1569              КАРИНА       ADIATOVA375@email.COM   Атырауская
# 1571             Гульнур  gulnur-sagyndykova@mail.ru  Алматинская
# 1572          айана кали     aisana220807@icloud.com   Атырауская
# 1573                Дана      danaserik028@gmail.com   Атырауская
# 1612              Әлижан    alizhanmikoyan@gmail.com   Атырауская
#
#                                 place      role language  gender age
# 0                                       teacher  russian  female  31  \
# ...

# %%
# dropping rows with the same values in the name column

df2 = df.drop_duplicates("name")
df2
# Out:
#                     name                       email                  region
# 0     daniyar.kakimbekov            asdasd@asdsd.com             Алматинская  \
# 30    elnazik_94@mail.ru          elnazik_94@mail.ru                  Алматы
# 32                Yelnaz          elnazik_94@mail.ru                  Алматы
# 33                 Айжан         torekhan_ae@mail.ru  Восточно-Казахстанская
# 35                  Асия           asiya1395@mail.ru                  Алматы
# ...                  ...                         ...                     ...
# 1569              КАРИНА       ADIATOVA375@email.COM              Атырауская
# 1571             Гульнур  gulnur-sagyndykova@mail.ru             Алматинская
# 1572          айана кали     aisana220807@icloud.com              Атырауская
# 1573                Дана      danaserik028@gmail.com              Атырауская
# 1612              Әлижан    alizhanmikoyan@gmail.com              Атырауская
#
# ...
