# %%
import pandas as pd
import numpy as np

# %%
final = pd.read_csv("final_full.csv")

df_filtered = final.drop(final[final['role'] == 'teacher'].index)
df_filtered = df_filtered.drop(final[final['role'] == ' teacher'].index)
# Out:
# /var/folders/b6/486jxbhd03z06w9634qqg4km0000gn/T/ipykernel_1382/101916566.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   final = pd.read_csv("final_full.csv")

# %% [markdown]
# # Some statistical things

# %%
print(f"Number of teachers registered for the Hour of Code: {len(final) - len(df_filtered)}")
print(f"Number of students registered for the Hour of Code: {len(df_filtered)}")
# Out:
# Number of teachers registered for the Hour of Code: 10490
# Number of students registered for the Hour of Code: 251506

# %%
final.columns
# Out:
# Index(['Unnamed: 0', 'name', 'email', 'region', 'place', 'role', 'language',
#        'gender', 'age', 'school', ' date', ' time'],
#       dtype='object')

# %%
final = final.drop(["Unnamed: 0"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 final = final.drop(["Unnamed: 0"], axis=1)
#       2 final
#
# File ~/anaconda3/envs/ml/lib/python3.11/site-packages/pandas/core/frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
#    5352         level=level,
#    5353         inplace=inplace,
# ...

# %%
final.to_csv("clean_final.csv", index=False)

# %% [markdown]
# # Regions stuff

# %%
regionDF = pd.read_csv("clean_final.csv")
regionDF = regionDF.drop(["email", "name", "age", " time"], axis = 1)
regionDF
# Out:
# /var/folders/b6/486jxbhd03z06w9634qqg4km0000gn/T/ipykernel_1382/1329923804.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   regionDF = pd.read_csv("clean_final.csv")
#                region     place      role language  gender      school  \
# 0         Алматинская             teacher  russian  female      asdasd
# 1         Алматинская             teacher  russian    male      asdasd
# 2              Алматы             teacher  russian    male         asd
# 3              Астана             teacher  russian    male   asdaspdoj
# 4              Алматы             teacher  russian    male   asdaspdoj
# ...               ...       ...       ...      ...     ...         ...
# 261991         Алматы    Алматы   student  russian  female  КГУ ШГ № 6
# 261992         Алматы    Алматы   student  russian  female  КГУ ШГ № 6
# 261993         Алматы    Алматы   student  russian  female  КГУ ШГ № 6
# ...

# %%
regionDF["region"].unique()
# Out:
# array(['Алматинская', 'Алматы', 'Астана', 'Восточно-Казахстанская',
#        'Шымкент', 'Абайская', 'Северо-Казахстанская', 'Павлодарская',
#        'Костанайская', 'Атырауская', 'Карагандинская',
#        'Западно-Казахстанская', 'Туркестанская', 'Акмолинская',
#        'Кызылординская', 'Жетысуская', 'Жамбылская', 'Актюбинская',
#        'Улытауская', 'Мангистауская', 'Южно-Казахстанская'], dtype=object)

# %%
almaty = regionDF[regionDF["region"] == "Алматы"]
almaty["place"].value_counts()
# Out:
# place
#  Алматы                 5231
#  алматы                  724
#  .                       546
#  Алматы                  446
#                          295
#                         ...
#  Улица Нурмагомедов        1
#  Никакой                   1
#  118                       1
#  Кемеңгер 44               1
#  Курчатов                  1
# Name: count, Length: 3374, dtype: int64

# %%
placesListAlmaty = almaty["place"].unique()

for p in range(len(placesListAlmaty)):
    print(placesListAlmaty[p])
# Out:
#
#  Алатау ауданы
#  Алатауский район
#  Алматинская область
#  Медеу ауданы
#  Екпінді
#  зерделы
#  Алатау
#  зердели
#  алматы
#  алатау ауданы
#  алитьбюдлорпаввыффцукенгшщзхъаты
#  бекарыс
#  almaty
#  дарабоз
#  Алматы
#  Турксиб
#  Наурызбайский район
#  Алматы
#  город
#  Казахстан
#  Мкр Зерделі
#  Бостандыкский район
#  206 мектеп-гимназия
#  Актау
#  мартобе
#  Қонаев
#  Aqtau
#  актау
#  Наурызбай ауданы
#  Алматинская
#  Боролдай
#  водник 2
#  Боролдай
#  Алматы қаласы
#  Водник
#  Karasay
#  Қапал батыр атындағы орта мектеп
#  Алматы облысы
#  Илийский Район
#  Қырық ауыл
#  Almaty
#  -
#  Алматы қаласы
#  Алматы облысы
#  Жетису ау даны
#  Қарасай
#  Қарасай облысы
#  Қарасай ауданы
#  Карасай
#  Жамбыл
#  Карасаи обылыс
#  Қарасай облысы
#  Қарасаи облысы
#  Қарасай  ауданы Жамбыл ауылы
#  алмата
#  Қараса ауданы
#  Қарасай ауданы
#  Қарасай
#  ауэзовский
#  Қарасай ауданы Жамбыл ауданы
#  Қарасац облысы
#  Қарасай ауданы Жамбыл ауылы
#  Карасаи ауданы
# ...
