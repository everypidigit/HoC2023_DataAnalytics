# %%
import pandas as pd

# %%
# reading data

df = pd.read_csv("data.csv")
df
# Out:
#                    name                         email                  region
# 0    daniyar.kakimbekov              asdasd@asdsd.com             Алматинская  \
# 1    daniyar.kakimbekov              asdasd@asdsd.com             Алматинская
# 2    daniyar.kakimbekov              asdasd@asdsd.com             Алматинская
# 3    daniyar.kakimbekov              asdasd@asdsd.com             Алматинская
# 4    daniyar.kakimbekov              asdasd@asdsd.com             Алматинская
# ..                  ...                           ...                     ...
# 503              Нурлан           n.zeinelhan@mail.ru              Жетысуская
# 504               Adema     adematanabayeva@gmail.com   Западно-Казахстанская
# 505              Никита  kopytov.nikita2010@gmail.com                  Алматы
# 506              Зәуреш         zauresh.00.00@mail.ru  Восточно-Казахстанская
# 507                 Лев    o.kungurtseva.79@gmail.com  Восточно-Казахстанская
#
#                     place      role language  gender  age
# 0                           teacher  russian  female   31  \
# 1                           teacher  russian  female   31
# 2                           teacher  russian    male   31
# 3                           teacher  russian    male   31
# 4                           teacher  russian    male   31
# ..                    ...       ...      ...     ...  ...
# 503                Сарқан   teacher   kazakh    male   46
# 504                Taldyk   teacher  russian  female   18
# 505   Алматинская область   student  russian    male   13
# 506               г.Алтай   teacher  russian  female   23
# 507                 Город   student  russian    male   12
#
#                                     school
# 0                                   asdasd
# 1                                   asdasd
# 2                                   asdasd
# 3                                   asdasd
# 4                                   asdasd
# ..                                     ...
# 503    Н.Островский атындағы мектеп-лицей
# 504                                      8
# 505  КГУ Школа-Лицей № 28 им. М. Маметовой
# 506    КГУ "Средняя школа №7 города Алтай"
# 507                               Школа №6
#
# [508 rows x 9 columns]

# %%
# dropping rows in which all columns have the same values

df1 = df.drop_duplicates()

df1.to_csv("cleaned_data.csv", index=False)
df1
# Out:
#                    name                         email                  region
# 0    daniyar.kakimbekov              asdasd@asdsd.com             Алматинская  \
# 2    daniyar.kakimbekov              asdasd@asdsd.com             Алматинская
# 5    daniyar.kakimbekov              asdasd@asdsd.com                  Алматы
# 11   daniyar.kakimbekov              asdasd@asdsd.com                  Астана
# 17   daniyar.kakimbekov              asdasd@asdsd.com                  Алматы
# ..                  ...                           ...                     ...
# 503              Нурлан           n.zeinelhan@mail.ru              Жетысуская
# 504               Adema     adematanabayeva@gmail.com   Западно-Казахстанская
# 505              Никита  kopytov.nikita2010@gmail.com                  Алматы
# 506              Зәуреш         zauresh.00.00@mail.ru  Восточно-Казахстанская
# 507                 Лев    o.kungurtseva.79@gmail.com  Восточно-Казахстанская
#
#                     place      role language  gender  age
# 0                           teacher  russian  female   31  \
# 2                           teacher  russian    male   31
# 5                           teacher  russian    male   31
# 11                          teacher  russian    male   31
# 17                          teacher  russian    male   31
# ..                    ...       ...      ...     ...  ...
# 503                Сарқан   teacher   kazakh    male   46
# 504                Taldyk   teacher  russian  female   18
# 505   Алматинская область   student  russian    male   13
# 506               г.Алтай   teacher  russian  female   23
# 507                 Город   student  russian    male   12
#
#                                     school
# 0                                   asdasd
# 2                                   asdasd
# 5                                      asd
# 11                               asdaspdoj
# 17                               asdaspdoj
# ..                                     ...
# 503    Н.Островский атындағы мектеп-лицей
# 504                                      8
# 505  КГУ Школа-Лицей № 28 им. М. Маметовой
# 506    КГУ "Средняя школа №7 города Алтай"
# 507                               Школа №6
#
# [354 rows x 9 columns]

# %%
# dropping rows with the same values in the name column

df2 = df.drop_duplicates("name")
df2
# Out:
#                    name                         email                  region
# 0    daniyar.kakimbekov              asdasd@asdsd.com             Алматинская  \
# 30   elnazik_94@mail.ru            elnazik_94@mail.ru                  Алматы
# 32               Yelnaz            elnazik_94@mail.ru                  Алматы
# 33                Айжан           torekhan_ae@mail.ru  Восточно-Казахстанская
# 35                 Асия             asiya1395@mail.ru                  Алматы
# ..                  ...                           ...                     ...
# 503              Нурлан           n.zeinelhan@mail.ru              Жетысуская
# 504               Adema     adematanabayeva@gmail.com   Западно-Казахстанская
# 505              Никита  kopytov.nikita2010@gmail.com                  Алматы
# 506              Зәуреш         zauresh.00.00@mail.ru  Восточно-Казахстанская
# 507                 Лев    o.kungurtseva.79@gmail.com  Восточно-Казахстанская
#
#                     place      role language  gender  age
# 0                           teacher  russian  female   31  \
# 30                          teacher   kazakh  female   29
# 32                          teacher   kazakh  female   29
# 33                          teacher   kazakh  female   26
# 35                          teacher  russian  female   28
# ..                    ...       ...      ...     ...  ...
# 503                Сарқан   teacher   kazakh    male   46
# 504                Taldyk   teacher  russian  female   18
# 505   Алматинская область   student  russian    male   13
# 506               г.Алтай   teacher  russian  female   23
# 507                 Город   student  russian    male   12
#
#                                     school
# 0                                   asdasd
# 30                                     104
# 32                                     104
# 33                                       4
# 35                            Гимнзия №132
# ..                                     ...
# 503    Н.Островский атындағы мектеп-лицей
# 504                                      8
# 505  КГУ Школа-Лицей № 28 им. М. Маметовой
# 506    КГУ "Средняя школа №7 города Алтай"
# 507                               Школа №6
#
# [339 rows x 9 columns]
